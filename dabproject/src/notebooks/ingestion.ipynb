# %%
# Declare the widget (receives the value from job.yml)
dbutils.widgets.text("catalog_name", "")          # "" is the default fallback

# Read it
catalog_name = dbutils.widgets.get("catalog_name")

# %%
# %sql
Select * from assetbundles.information_schema.columns

# %%
spark.sql(f"SELECT * FROM {catalog_name}.information_schema.columns" )
